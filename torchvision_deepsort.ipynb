# %%
# !pip install deep-sort-realtime
# Out:
# Collecting deep-sort-realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deep-sort-realtime) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from deep-sort-realtime) (1.11.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from deep-sort-realtime) (4.8.0.76)
# Installing collected packages: deep-sort-realtime
# Successfully installed deep-sort-realtime-1.3.2

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-gjfcxg9d
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-gjfcxg9d
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.15.2+cu118)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->clip==1.0) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->clip==1.0) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=ed11b19648750f4aa9d25b341565845e1251f4fc51329c5a20a848e4dac0e975
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hrer5rdt/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.1.1

# %%
# !git clone https://github.com/KaiyangZhou/deep-person-reid.git
# %cd deep-person-reid/
# Out:
# Cloning into 'deep-person-reid'...
# remote: Enumerating objects: 9876, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 9876 (delta 8), reused 13 (delta 7), pack-reused 9851
# Receiving objects: 100% (9876/9876), 9.57 MiB | 14.23 MiB/s, done.
# Resolving deltas: 100% (7294/7294), done.
# /content/deep-person-reid

# %%
# !python setup.py develop
# Out:
# /content/deep-person-reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# 2023-09-15 06:57:22.941145: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-15 06:57:23.858908: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Compiling torchreid/metrics/rank_cylib/rank_cy.pyx because it changed.
# [1/1] Cythonizing torchreid/metrics/rank_cylib/rank_cy.pyx
# /usr/local/lib/python3.10/dist-packages/Cython/Compiler/Main.py:384: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/deep-person-reid/torchreid/metrics/rank_cylib/rank_cy.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# creating torchreid.egg-info
# writing torchreid.egg-info/PKG-INFO
# writing dependency_links to torchreid.egg-info/dependency_links.txt
# writing requirements to torchreid.egg-info/requires.txt
# writing top-level names to torchreid.egg-info/top_level.txt
# writing manifest file 'torchreid.egg-info/SOURCES.txt'
# reading manifest file 'torchreid.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'torchreid.egg-info/SOURCES.txt'
# running build_ext
# building 'torchreid.metrics.rank_cylib.rank_cy' extension
# creating build
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/torchreid
# creating build/temp.linux-x86_64-cpython-310/torchreid/metrics
# creating build/temp.linux-x86_64-cpython-310/torchreid/metrics/rank_cylib
# x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c torchreid/metrics/rank_cylib/rank_cy.c -o build/temp.linux-x86_64-cpython-310/torchreid/metrics/rank_cylib/rank_cy.o
# In file included from /usr/local/lib/python3.10/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1948,
#                  from /usr/local/lib/python3.10/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.10/dist-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from torchreid/metrics/rank_cylib/rank_cy.c:1177:
# /usr/local/lib/python3.10/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# creating build/lib.linux-x86_64-cpython-310
# creating build/lib.linux-x86_64-cpython-310/torchreid
# creating build/lib.linux-x86_64-cpython-310/torchreid/metrics
# creating build/lib.linux-x86_64-cpython-310/torchreid/metrics/rank_cylib
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-310/torchreid/metrics/rank_cylib/rank_cy.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-310/torchreid/metrics/rank_cylib/rank_cy.cpython-310-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-310/torchreid/metrics/rank_cylib/rank_cy.cpython-310-x86_64-linux-gnu.so -> torchreid/metrics/rank_cylib
# Creating /usr/local/lib/python3.10/dist-packages/torchreid.egg-link (link to .)
# Adding torchreid 1.4.0 to easy-install.pth file
#
# Installed /content/deep-person-reid
# Processing dependencies for torchreid==1.4.0
# Searching for isort==4.3.21
# Reading https://pypi.org/simple/isort/
# Downloading https://files.pythonhosted.org/packages/e5/b0/c121fd1fa3419ea9bfd55c7f9c4fedfec5143208d8c7ad3ce3db6c623c21/isort-4.3.21-py2.py3-none-any.whl#sha256=6e811fcb295968434526407adb8796944f1988c5b65e8139058f2014cbe100fd
# Best match: isort 4.3.21
# Processing isort-4.3.21-py2.py3-none-any.whl
# Installing isort-4.3.21-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding isort 4.3.21 to easy-install.pth file
# Installing isort script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/isort-4.3.21-py3.10.egg
# Searching for yapf
# Reading https://pypi.org/simple/yapf/
# Downloading https://files.pythonhosted.org/packages/23/75/c374517c09e31bf22d3b3f156d73e0f38d08e29b2afdd607cef5f1e10aa9/yapf-0.40.1-py3-none-any.whl#sha256=b8bfc1f280949153e795181768ca14ef43d7312629a06c43e7abd279323af313
# Best match: yapf 0.40.1
# Processing yapf-0.40.1-py3-none-any.whl
# Installing yapf-0.40.1-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding yapf 0.40.1 to easy-install.pth file
# Installing yapf script to /usr/local/bin
# Installing yapf-diff script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/yapf-0.40.1-py3.10.egg
# Searching for flake8
# Reading https://pypi.org/simple/flake8/
# Downloading https://files.pythonhosted.org/packages/b0/24/bbf7175ffc47cb3d3e1eb523ddb23272968359dfcf2e1294707a2bf12fc4/flake8-6.1.0-py2.py3-none-any.whl#sha256=ffdfce58ea94c6580c77888a86506937f9a1a227dfcd15f245d694ae20a6b6e5
# Best match: flake8 6.1.0
# Processing flake8-6.1.0-py2.py3-none-any.whl
# Installing flake8-6.1.0-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding flake8 6.1.0 to easy-install.pth file
# Installing flake8 script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/flake8-6.1.0-py3.10.egg
# Searching for yacs
# Reading https://pypi.org/simple/yacs/
# Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl#sha256=99f893e30497a4b66842821bac316386f7bd5c4f47ad35c9073ef089aa33af32
# Best match: yacs 0.1.8
# Processing yacs-0.1.8-py3-none-any.whl
# Installing yacs-0.1.8-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding yacs 0.1.8 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/yacs-0.1.8-py3.10.egg
# Searching for tb-nightly
# Reading https://pypi.org/simple/tb-nightly/
# Downloading https://files.pythonhosted.org/packages/fe/38/1b8a2e94c767c6fb6ae043be3ee0d7916bd73a377eb5f072367a8ecb1730/tb_nightly-2.15.0a20230914-py3-none-any.whl#sha256=ed9eb6099d60dbb7d47f91edeba13e27cc24bc5068889b31241a5593669c9e3f
# Best match: tb-nightly 2.15.0a20230914
# Processing tb_nightly-2.15.0a20230914-py3-none-any.whl
# Installing tb_nightly-2.15.0a20230914-py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding tb-nightly 2.15.0a20230914 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/tb_nightly-2.15.0a20230914-py3.10.egg
# Searching for pyflakes<3.2.0,>=3.1.0
# Reading https://pypi.org/simple/pyflakes/
# Downloading https://files.pythonhosted.org/packages/00/e9/1e1fd7fae559bfd07704991e9a59dd1349b72423c904256c073ce88a9940/pyflakes-3.1.0-py2.py3-none-any.whl#sha256=4132f6d49cb4dae6819e5379898f2b8cce3c5f23994194c24b77d5da2e36f774
# Best match: pyflakes 3.1.0
# Processing pyflakes-3.1.0-py2.py3-none-any.whl
# Installing pyflakes-3.1.0-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding pyflakes 3.1.0 to easy-install.pth file
# Installing pyflakes script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/pyflakes-3.1.0-py3.10.egg
# Searching for pycodestyle<2.12.0,>=2.11.0
# Reading https://pypi.org/simple/pycodestyle/
# Downloading https://files.pythonhosted.org/packages/31/c2/e1508ed4395793f69e40fd8c6b5a690e1d568e649aae9492076a7b6befb4/pycodestyle-2.11.0-py2.py3-none-any.whl#sha256=5d1013ba8dc7895b548be5afb05740ca82454fd899971563d2ef625d090326f8
# Best match: pycodestyle 2.11.0
# Processing pycodestyle-2.11.0-py2.py3-none-any.whl
# Installing pycodestyle-2.11.0-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding pycodestyle 2.11.0 to easy-install.pth file
# Installing pycodestyle script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/pycodestyle-2.11.0-py3.10.egg
# Searching for mccabe<0.8.0,>=0.7.0
# Reading https://pypi.org/simple/mccabe/
# Downloading https://files.pythonhosted.org/packages/27/1a/1f68f9ba0c207934b35b86a8ca3aad8395a3d6dd7921c0686e23853ff5a9/mccabe-0.7.0-py2.py3-none-any.whl#sha256=6c2d30ab6be0e4a46919781807b4f0d834ebdd6c6e3dca0bda5a15f863427b6e
# Best match: mccabe 0.7.0
# Processing mccabe-0.7.0-py2.py3-none-any.whl
# Installing mccabe-0.7.0-py2.py3-none-any.whl to /usr/local/lib/python3.10/dist-packages
# Adding mccabe 0.7.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/mccabe-0.7.0-py3.10.egg
# Searching for chardet==5.2.0
# Best match: chardet 5.2.0
# Adding chardet 5.2.0 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for imageio==2.31.3
# Best match: imageio 2.31.3
# Adding imageio 2.31.3 to easy-install.pth file
# Installing imageio_download_bin script to /usr/local/bin
# Installing imageio_remove_bin script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for gdown==4.6.6
# Best match: gdown 4.6.6
# Adding gdown 4.6.6 to easy-install.pth file
# Installing gdown script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for future==0.18.3
# Best match: future 0.18.3
# Adding future 0.18.3 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for opencv-python==4.8.0.76
# Best match: opencv-python 4.8.0.76
# Adding opencv-python 4.8.0.76 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.11.2
# Best match: scipy 1.11.2
# Adding scipy 1.11.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pillow==9.4.0
# Best match: Pillow 9.4.0
# Adding Pillow 9.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for h5py==3.9.0
# Best match: h5py 3.9.0
# Adding h5py 3.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Cython==3.0.2
# Best match: Cython 3.0.2
# Adding Cython 3.0.2 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tomli==2.0.1
# Best match: tomli 2.0.1
# Adding tomli 2.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for platformdirs==3.10.0
# Best match: platformdirs 3.10.0
# Adding platformdirs 3.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for importlib-metadata==6.8.0
# Best match: importlib-metadata 6.8.0
# Adding importlib-metadata 6.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for beautifulsoup4==4.11.2
# Best match: beautifulsoup4 4.11.2
# Adding beautifulsoup4 4.11.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tqdm==4.66.1
# Best match: tqdm 4.66.1
# Adding tqdm 4.66.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for filelock==3.12.2
# Best match: filelock 3.12.2
# Adding filelock 3.12.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyYAML==6.0.1
# Best match: PyYAML 6.0.1
# Adding PyYAML 6.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for wheel==0.41.2
# Best match: wheel 0.41.2
# Adding wheel 0.41.2 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for werkzeug==2.3.7
# Best match: werkzeug 2.3.7
# Adding werkzeug 2.3.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard-data-server==0.7.1
# Best match: tensorboard-data-server 0.7.1
# Adding tensorboard-data-server 0.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for setuptools==67.7.2
# Best match: setuptools 67.7.2
# Adding setuptools 67.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for protobuf==3.20.3
# Best match: protobuf 3.20.3
# Adding protobuf 3.20.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Markdown==3.4.4
# Best match: Markdown 3.4.4
# Adding Markdown 3.4.4 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth-oauthlib==1.0.0
# Best match: google-auth-oauthlib 1.0.0
# Adding google-auth-oauthlib 1.0.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth==2.17.3
# Best match: google-auth 2.17.3
# Adding google-auth 2.17.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for grpcio==1.57.0
# Best match: grpcio 1.57.0
# Adding grpcio 1.57.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyparsing==3.1.1
# Best match: pyparsing 3.1.1
# Adding pyparsing 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.1
# Best match: packaging 23.1
# Adding packaging 23.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for kiwisolver==1.4.5
# Best match: kiwisolver 1.4.5
# Adding kiwisolver 1.4.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fonttools==4.42.1
# Best match: fonttools 4.42.1
# Adding fonttools 4.42.1 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contourpy==1.1.0
# Best match: contourpy 1.1.0
# Adding contourpy 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for zipp==3.16.2
# Best match: zipp 3.16.2
# Adding zipp 3.16.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for soupsieve==2.5
# Best match: soupsieve 2.5
# Adding soupsieve 2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PySocks==1.7.1
# Best match: PySocks 1.7.1
# Adding PySocks 1.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2023.7.22
# Best match: certifi 2023.7.22
# Adding certifi 2023.7.22 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.4
# Best match: urllib3 2.0.4
# Adding urllib3 2.0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.2.0
# Best match: charset-normalizer 3.2.0
# Adding charset-normalizer 3.2.0 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for MarkupSafe==2.1.3
# Best match: MarkupSafe 2.1.3
# Adding MarkupSafe 2.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1-modules==0.3.0
# Best match: pyasn1-modules 0.3.0
# Adding pyasn1-modules 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cachetools==5.3.1
# Best match: cachetools 5.3.1
# Adding cachetools 5.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1==0.5.0
# Best match: pyasn1 0.5.0
# Adding pyasn1 0.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for torchreid==1.4.0

# %%
# %%writefile detect_sort_tracking.py
"""
Deep SORT with various object detection models.

USAGE:
python deep_sort_tracking.py
python deep_sort_tracking.py --threshold 0.5 --imgsz 320
python deep_sort_tracking.py --threshold 0.5 --model fasterrcnn_resnet50_fpn_v2
                                                     fasterrcnn_resnet50_fpn
                                                     fasterrcnn_mobilenet_v3_large_fpn
                                                     fasterrcnn_mobilenet_v3_large_320_fpn
                                                     fcos_resnet50_fpn
                                                     ssd300_vgg16
                                                     ssdlite320_mobilenet_v3_large
                                                     retinanet_resnet50_fpn
                                                     retinanet_resnet50_fpn_v2
"""

import torch
import torchvision
import cv2
import os
import time
import argparse
import numpy as np

from torchvision.transforms import ToTensor
from deep_sort_realtime.deepsort_tracker import DeepSort
from utils import convert_detections, annotate
from coco_classes import COCO_91_CLASSES

parser = argparse.ArgumentParser()
parser.add_argument(
    '--input',
    default='input/mvmhat_1_1.mp4',
    help='path to input video',
)
parser.add_argument(
    '--imgsz',
    default=None,
    help='image resize, 640 will resize images to 640x640',
    type=int
)
parser.add_argument(
    '--model',
    default='fasterrcnn_resnet50_fpn_v2',
    help='model name',
    choices=[
        'fasterrcnn_resnet50_fpn_v2',
        'fasterrcnn_resnet50_fpn',
        'fasterrcnn_mobilenet_v3_large_fpn',
        'fasterrcnn_mobilenet_v3_large_320_fpn',
        'fcos_resnet50_fpn',
        'ssd300_vgg16',
        'ssdlite320_mobilenet_v3_large',
        'retinanet_resnet50_fpn',
        'retinanet_resnet50_fpn_v2'
    ]
)
parser.add_argument(
    '--threshold',
    default=0.8,
    help='score threshold to filter out detections',
    type=float
)
parser.add_argument(
    '--embedder',
    default='mobilenet',
    help='type of feature extractor to use',
    choices=[
        "mobilenet",
        "torchreid",
        "clip_RN50",
        "clip_RN101",
        "clip_RN50x4",
        "clip_RN50x16",
        "clip_ViT-B/32",
        "clip_ViT-B/16"
    ]
)
parser.add_argument(
    '--show',
    action='store_true',
    help='visualize results in real-time on screen'
)
parser.add_argument(
    '--cls',
    nargs='+',
    default=[1],
    help='which classes to track',
    type=int
)
args = parser.parse_args()

np.random.seed(42)

OUT_DIR = 'outputs'
os.makedirs(OUT_DIR, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
COLORS = np.random.randint(0, 255, size=(len(COCO_91_CLASSES), 3))

print(f"Tracking: {[COCO_91_CLASSES[idx] for idx in args.cls]}")
print(f"Detector: {args.model}")
print(f"Re-ID embedder: {args.embedder}")

# Load model.
model = getattr(torchvision.models.detection, args.model)(weights='DEFAULT')
# Set model to evaluation mode.
model.eval().to(device)

# Initialize a SORT tracker object.
tracker = DeepSort(max_age=30, embedder=args.embedder)

VIDEO_PATH = args.input
cap = cv2.VideoCapture(VIDEO_PATH)
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
frame_fps = int(cap.get(5))
frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
save_name = VIDEO_PATH.split(os.path.sep)[-1].split('.')[0]
# Define codec and create VideoWriter object.
out = cv2.VideoWriter(
    f"{OUT_DIR}/{save_name}_{args.model}_{args.embedder}.mp4",
    cv2.VideoWriter_fourcc(*'mp4v'), frame_fps,
    (frame_width, frame_height)
)

frame_count = 0 # To count total frames.
total_fps = 0 # To get the final frames per second.
while cap.isOpened():
    # Read a frame
    ret, frame = cap.read()
    if ret:
        if args.imgsz != None:
            resized_frame = cv2.resize(
                cv2.cvtColor(frame, cv2.COLOR_BGR2RGB),
                (args.imgsz, args.imgsz)
            )
        else:
            resized_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Convert frame to tensor and send it to device (cpu or cuda).
        frame_tensor = ToTensor()(resized_frame).to(device)

        start_time = time.time()
        # Feed frame to model and get detections.
        det_start_time = time.time()
        with torch.no_grad():
            detections = model([frame_tensor])[0]
        det_end_time = time.time()

        det_fps = 1 / (det_end_time - det_start_time)

        # Convert detections to Deep SORT format.
        detections = convert_detections(detections, args.threshold, args.cls)

        # Update tracker with detections.
        track_start_time = time.time()
        tracks = tracker.update_tracks(detections, frame=frame)
        track_end_time = time.time()
        track_fps = 1 / (track_end_time - track_start_time)

        end_time = time.time()
        fps = 1 / (end_time - start_time)
        # Add `fps` to `total_fps`.
        total_fps += fps
        # Increment frame count.
        frame_count += 1

        print(f"Frame {frame_count}/{frames}",
              f"Detection FPS: {det_fps:.1f},",
              f"Tracking FPS: {track_fps:.1f}, Total FPS: {fps:.1f}")
        # Draw bounding boxes and labels on frame.
        if len(tracks) > 0:
            frame = annotate(
                tracks,
                frame,
                resized_frame,
                frame_width,
                frame_height,
                COLORS
            )
        cv2.putText(
            frame,
            f"FPS: {fps:.1f}",
            (int(20), int(40)),
            fontFace=cv2.FONT_HERSHEY_SIMPLEX,
            fontScale=1,
            color=(0, 0, 255),
            thickness=2,
            lineType=cv2.LINE_AA
        )
        out.write(frame)
        if args.show:
            # Display or save output frame.
            cv2.imshow("Output", frame)
            # Press q to quit.
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
    else:
        break

# Release resources.
cap.release()
cv2.destroyAllWindows()
# Out:
# Writing detect_sort_tracking.py

# %%
# %%writefile coco_classes.py
COCO_91_CLASSES = [
    '__background__',
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]
# Out:
# Writing coco_classes.py

# %%
# %%writefile utils.py
import cv2
import numpy as np

# Define a function to convert detections to SORT format.
def convert_detections(detections, threshold, classes):
    # Get the bounding boxes, labels and scores from the detections dictionary.
    boxes = detections["boxes"].cpu().numpy()
    labels = detections["labels"].cpu().numpy()
    scores = detections["scores"].cpu().numpy()
    lbl_mask = np.isin(labels, classes)
    scores = scores[lbl_mask]
    # Filter out low confidence scores and non-person classes.
    mask = scores > threshold
    boxes = boxes[lbl_mask][mask]
    scores = scores[mask]
    labels = labels[lbl_mask][mask]

    # Convert boxes to [x1, y1, w, h, score] format.
    final_boxes = []
    for i, box in enumerate(boxes):
        # Append ([x, y, w, h], score, label_string).
        final_boxes.append(
            (
                [box[0], box[1], box[2] - box[0], box[3] - box[1]],
                scores[i],
                str(labels[i])
            )
        )

    return final_boxes

# Function for bounding box and ID annotation.
def annotate(tracks, frame, resized_frame, frame_width, frame_height, colors):
    for track in tracks:
        if not track.is_confirmed():
            continue
        track_id = track.track_id
        track_class = track.det_class
        x1, y1, x2, y2 = track.to_ltrb()
        p1 = (int(x1/resized_frame.shape[1]*frame_width), int(y1/resized_frame.shape[0]*frame_height))
        p2 = (int(x2/resized_frame.shape[1]*frame_width), int(y2/resized_frame.shape[0]*frame_height))
        # Annotate boxes.
        color = colors[int(track_class)]
        cv2.rectangle(
            frame,
            p1,
            p2,
            color=(int(color[0]), int(color[1]), int(color[2])),
            thickness=2
        )
        # Annotate ID.
        cv2.putText(
            frame, f"ID: {track_id}",
            (p1[0], p1[1] - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (0, 255, 0),
            2,
            lineType=cv2.LINE_AA
        )
    return frame
# Out:
# Writing utils.py

# %%
# !python detect_sort_tracking.py --input /content/sprint.mp4
# Out:
# Tracking: ['person']
# Detector: fasterrcnn_resnet50_fpn_v2
# Re-ID embedder: mobilenet
# Frame 1/344 Detection FPS: 4.3, Tracking FPS: 9.0, Total FPS: 2.9
# Frame 2/344 Detection FPS: 6.9, Tracking FPS: 18.7, Total FPS: 5.0
# Frame 3/344 Detection FPS: 6.7, Tracking FPS: 25.4, Total FPS: 5.3
# Frame 4/344 Detection FPS: 6.8, Tracking FPS: 5.5, Total FPS: 3.0
# Frame 5/344 Detection FPS: 6.6, Tracking FPS: 5.3, Total FPS: 3.0
# Frame 6/344 Detection FPS: 6.8, Tracking FPS: 5.9, Total FPS: 3.2
# Frame 7/344 Detection FPS: 6.7, Tracking FPS: 6.0, Total FPS: 3.2
# Frame 8/344 Detection FPS: 6.7, Tracking FPS: 19.9, Total FPS: 5.0
# Frame 9/344 Detection FPS: 6.7, Tracking FPS: 17.2, Total FPS: 4.8
# Frame 10/344 Detection FPS: 6.7, Tracking FPS: 17.6, Total FPS: 4.8
# Frame 11/344 Detection FPS: 6.7, Tracking FPS: 17.9, Total FPS: 4.8
# Frame 12/344 Detection FPS: 6.8, Tracking FPS: 16.7, Total FPS: 4.8
# Frame 13/344 Detection FPS: 6.7, Tracking FPS: 25.8, Total FPS: 5.3
# Frame 14/344 Detection FPS: 6.7, Tracking FPS: 31.1, Total FPS: 5.5
# Frame 15/344 Detection FPS: 6.9, Tracking FPS: 20.9, Total FPS: 5.2
# Frame 16/344 Detection FPS: 6.8, Tracking FPS: 8.3, Total FPS: 3.7
# Frame 17/344 Detection FPS: 6.8, Tracking FPS: 32.7, Total FPS: 5.6
# Frame 18/344 Detection FPS: 6.9, Tracking FPS: 26.5, Total FPS: 5.5
# Frame 19/344 Detection FPS: 6.8, Tracking FPS: 26.0, Total FPS: 5.4
# Frame 20/344 Detection FPS: 6.8, Tracking FPS: 25.9, Total FPS: 5.4
# Frame 21/344 Detection FPS: 6.8, Tracking FPS: 24.0, Total FPS: 5.3
# Frame 22/344 Detection FPS: 6.9, Tracking FPS: 25.8, Total FPS: 5.4
# Frame 23/344 Detection FPS: 6.8, Tracking FPS: 26.2, Total FPS: 5.4
# Frame 24/344 Detection FPS: 6.9, Tracking FPS: 22.4, Total FPS: 5.3
# Frame 25/344 Detection FPS: 6.7, Tracking FPS: 23.0, Total FPS: 5.2
# Frame 26/344 Detection FPS: 6.8, Tracking FPS: 26.7, Total FPS: 5.4
# Frame 27/344 Detection FPS: 6.7, Tracking FPS: 23.3, Total FPS: 5.2
# Frame 28/344 Detection FPS: 6.7, Tracking FPS: 17.1, Total FPS: 4.8
# Frame 29/344 Detection FPS: 6.7, Tracking FPS: 26.8, Total FPS: 5.4
# Frame 30/344 Detection FPS: 6.8, Tracking FPS: 21.6, Total FPS: 5.2
# Frame 31/344 Detection FPS: 6.8, Tracking FPS: 18.1, Total FPS: 4.9
# Frame 32/344 Detection FPS: 6.8, Tracking FPS: 17.9, Total FPS: 4.9
# Frame 33/344 Detection FPS: 6.7, Tracking FPS: 22.2, Total FPS: 5.2
# Frame 34/344 Detection FPS: 6.8, Tracking FPS: 8.3, Total FPS: 3.7
# Frame 35/344 Detection FPS: 6.8, Tracking FPS: 7.0, Total FPS: 3.5
# Frame 36/344 Detection FPS: 6.7, Tracking FPS: 14.8, Total FPS: 4.6
# Frame 37/344 Detection FPS: 6.5, Tracking FPS: 7.0, Total FPS: 3.4
# Frame 38/344 Detection FPS: 6.8, Tracking FPS: 6.6, Total FPS: 3.3
# Frame 39/344 Detection FPS: 6.6, Tracking FPS: 14.1, Total FPS: 4.5
# Frame 40/344 Detection FPS: 6.7, Tracking FPS: 15.0, Total FPS: 4.6
# Frame 41/344 Detection FPS: 6.9, Tracking FPS: 7.2, Total FPS: 3.5
# Frame 42/344 Detection FPS: 6.8, Tracking FPS: 15.9, Total FPS: 4.8
# Frame 43/344 Detection FPS: 6.8, Tracking FPS: 14.6, Total FPS: 4.6
# Frame 44/344 Detection FPS: 6.7, Tracking FPS: 12.0, Total FPS: 4.3
# Frame 45/344 Detection FPS: 6.6, Tracking FPS: 14.1, Total FPS: 4.5
# Frame 46/344 Detection FPS: 6.6, Tracking FPS: 18.2, Total FPS: 4.8
# Frame 47/344 Detection FPS: 6.8, Tracking FPS: 20.6, Total FPS: 5.1
# Frame 48/344 Detection FPS: 6.8, Tracking FPS: 20.7, Total FPS: 5.1
# Frame 49/344 Detection FPS: 6.8, Tracking FPS: 20.1, Total FPS: 5.0
# Frame 50/344 Detection FPS: 6.8, Tracking FPS: 15.0, Total FPS: 4.7
# Frame 51/344 Detection FPS: 6.4, Tracking FPS: 17.6, Total FPS: 4.7
# Frame 52/344 Detection FPS: 6.8, Tracking FPS: 19.9, Total FPS: 5.1
# Frame 53/344 Detection FPS: 6.7, Tracking FPS: 8.5, Total FPS: 3.7
# Frame 54/344 Detection FPS: 6.5, Tracking FPS: 10.1, Total FPS: 4.0
# Frame 55/344 Detection FPS: 6.4, Tracking FPS: 7.4, Total FPS: 3.4
# Frame 56/344 Detection FPS: 6.6, Tracking FPS: 10.7, Total FPS: 4.1
# Frame 57/344 Detection FPS: 6.3, Tracking FPS: 8.5, Total FPS: 3.6
# Frame 58/344 Detection FPS: 6.8, Tracking FPS: 8.6, Total FPS: 3.8
# Frame 59/344 Detection FPS: 6.7, Tracking FPS: 7.8, Total FPS: 3.6
# Frame 60/344 Detection FPS: 6.7, Tracking FPS: 8.6, Total FPS: 3.8
# Frame 61/344 Detection FPS: 6.7, Tracking FPS: 8.4, Total FPS: 3.7
# Frame 62/344 Detection FPS: 6.5, Tracking FPS: 7.5, Total FPS: 3.5
# Frame 63/344 Detection FPS: 6.6, Tracking FPS: 15.8, Total FPS: 4.7
# Frame 64/344 Detection FPS: 6.7, Tracking FPS: 18.3, Total FPS: 4.9
# Frame 65/344 Detection FPS: 6.7, Tracking FPS: 20.6, Total FPS: 5.0
# Frame 66/344 Detection FPS: 6.8, Tracking FPS: 16.3, Total FPS: 4.8
# Frame 67/344 Detection FPS: 6.8, Tracking FPS: 15.4, Total FPS: 4.7
# Frame 68/344 Detection FPS: 6.7, Tracking FPS: 15.8, Total FPS: 4.7
# Frame 69/344 Detection FPS: 6.8, Tracking FPS: 17.9, Total FPS: 4.9
# Frame 70/344 Detection FPS: 6.8, Tracking FPS: 12.7, Total FPS: 4.4
# Frame 71/344 Detection FPS: 6.5, Tracking FPS: 20.9, Total FPS: 5.0
# Frame 72/344 Detection FPS: 6.8, Tracking FPS: 21.9, Total FPS: 5.2
# Frame 73/344 Detection FPS: 6.7, Tracking FPS: 21.3, Total FPS: 5.1
# Frame 74/344 Detection FPS: 6.7, Tracking FPS: 15.9, Total FPS: 4.7
# Frame 75/344 Detection FPS: 6.8, Tracking FPS: 21.8, Total FPS: 5.2
# Frame 76/344 Detection FPS: 6.8, Tracking FPS: 17.6, Total FPS: 4.9
# Frame 77/344 Detection FPS: 6.7, Tracking FPS: 16.8, Total FPS: 4.8
# Frame 78/344 Detection FPS: 6.8, Tracking FPS: 22.9, Total FPS: 5.3
# Frame 79/344 Detection FPS: 6.8, Tracking FPS: 22.2, Total FPS: 5.2
# Frame 80/344 Detection FPS: 6.8, Tracking FPS: 24.2, Total FPS: 5.3
# Frame 81/344 Detection FPS: 6.8, Tracking FPS: 7.5, Total FPS: 3.6
# Frame 82/344 Detection FPS: 6.6, Tracking FPS: 6.5, Total FPS: 3.3
# Frame 83/344 Detection FPS: 6.6, Tracking FPS: 15.0, Total FPS: 4.6
# Frame 84/344 Detection FPS: 6.7, Tracking FPS: 17.4, Total FPS: 4.8
# Frame 85/344 Detection FPS: 6.6, Tracking FPS: 7.6, Total FPS: 3.5
# Frame 86/344 Detection FPS: 6.6, Tracking FPS: 17.3, Total FPS: 4.8
# Frame 87/344 Detection FPS: 6.6, Tracking FPS: 28.0, Total FPS: 5.3
# Frame 88/344 Detection FPS: 6.6, Tracking FPS: 33.9, Total FPS: 5.5
# Frame 89/344 Detection FPS: 6.7, Tracking FPS: 33.0, Total FPS: 5.6
# Frame 90/344 Detection FPS: 6.7, Tracking FPS: 20.8, Total FPS: 5.0
# Frame 91/344 Detection FPS: 6.7, Tracking FPS: 20.8, Total FPS: 5.1
# Frame 92/344 Detection FPS: 6.7, Tracking FPS: 31.1, Total FPS: 5.5
# Frame 93/344 Detection FPS: 6.7, Tracking FPS: 28.8, Total FPS: 5.4
# Frame 94/344 Detection FPS: 6.7, Tracking FPS: 23.1, Total FPS: 5.2
# Frame 95/344 Detection FPS: 6.7, Tracking FPS: 19.9, Total FPS: 5.0
# Frame 96/344 Detection FPS: 6.7, Tracking FPS: 16.0, Total FPS: 4.7
# Frame 97/344 Detection FPS: 6.5, Tracking FPS: 26.4, Total FPS: 5.2
# Frame 98/344 Detection FPS: 6.6, Tracking FPS: 18.0, Total FPS: 4.8
# Frame 99/344 Detection FPS: 6.4, Tracking FPS: 17.6, Total FPS: 4.7
# Frame 100/344 Detection FPS: 6.8, Tracking FPS: 32.3, Total FPS: 5.6
# Frame 101/344 Detection FPS: 6.7, Tracking FPS: 21.7, Total FPS: 5.1
# Frame 102/344 Detection FPS: 6.6, Tracking FPS: 22.6, Total FPS: 5.1
# Frame 103/344 Detection FPS: 6.7, Tracking FPS: 19.2, Total FPS: 4.9
# Frame 104/344 Detection FPS: 6.4, Tracking FPS: 12.7, Total FPS: 4.2
# Frame 105/344 Detection FPS: 6.6, Tracking FPS: 12.5, Total FPS: 4.3
# Frame 106/344 Detection FPS: 7.1, Tracking FPS: 15.7, Total FPS: 4.9
# Frame 107/344 Detection FPS: 6.4, Tracking FPS: 12.8, Total FPS: 4.3
# Frame 108/344 Detection FPS: 6.8, Tracking FPS: 17.7, Total FPS: 4.9
# Frame 109/344 Detection FPS: 6.4, Tracking FPS: 14.0, Total FPS: 4.4
# Frame 110/344 Detection FPS: 6.6, Tracking FPS: 13.4, Total FPS: 4.4
# Frame 111/344 Detection FPS: 6.6, Tracking FPS: 18.0, Total FPS: 4.8
# Frame 112/344 Detection FPS: 6.2, Tracking FPS: 12.8, Total FPS: 4.2
# Frame 113/344 Detection FPS: 6.4, Tracking FPS: 12.6, Total FPS: 4.2
# Frame 114/344 Detection FPS: 6.4, Tracking FPS: 12.3, Total FPS: 4.2
# Frame 115/344 Detection FPS: 6.4, Tracking FPS: 21.5, Total FPS: 4.9
# Frame 116/344 Detection FPS: 6.5, Tracking FPS: 23.9, Total FPS: 5.1
# Frame 117/344 Detection FPS: 6.6, Tracking FPS: 26.8, Total FPS: 5.3
# Frame 118/344 Detection FPS: 6.7, Tracking FPS: 23.7, Total FPS: 5.2
# Frame 119/344 Detection FPS: 6.7, Tracking FPS: 28.4, Total FPS: 5.4
# Frame 120/344 Detection FPS: 6.7, Tracking FPS: 26.6, Total FPS: 5.3
# Frame 121/344 Detection FPS: 6.6, Tracking FPS: 25.6, Total FPS: 5.3
# Frame 122/344 Detection FPS: 6.8, Tracking FPS: 21.9, Total FPS: 5.2
# Frame 123/344 Detection FPS: 6.7, Tracking FPS: 18.1, Total FPS: 4.9
# Frame 124/344 Detection FPS: 6.5, Tracking FPS: 23.9, Total FPS: 5.1
# Frame 125/344 Detection FPS: 6.5, Tracking FPS: 24.2, Total FPS: 5.1
# Frame 126/344 Detection FPS: 6.6, Tracking FPS: 22.5, Total FPS: 5.1
# Frame 127/344 Detection FPS: 6.4, Tracking FPS: 22.8, Total FPS: 5.0
# Frame 128/344 Detection FPS: 6.5, Tracking FPS: 24.5, Total FPS: 5.1
# Frame 129/344 Detection FPS: 6.6, Tracking FPS: 23.0, Total FPS: 5.1
# Frame 130/344 Detection FPS: 6.6, Tracking FPS: 22.8, Total FPS: 5.1
# Frame 131/344 Detection FPS: 6.6, Tracking FPS: 25.3, Total FPS: 5.2
# Frame 132/344 Detection FPS: 6.6, Tracking FPS: 20.0, Total FPS: 5.0
# Frame 133/344 Detection FPS: 6.6, Tracking FPS: 20.7, Total FPS: 5.0
# Frame 134/344 Detection FPS: 6.5, Tracking FPS: 27.1, Total FPS: 5.3
# Frame 135/344 Detection FPS: 6.7, Tracking FPS: 22.2, Total FPS: 5.1
# Frame 136/344 Detection FPS: 6.8, Tracking FPS: 21.2, Total FPS: 5.1
# Frame 137/344 Detection FPS: 6.6, Tracking FPS: 20.6, Total FPS: 5.0
# Frame 138/344 Detection FPS: 6.6, Tracking FPS: 23.5, Total FPS: 5.2
# Frame 139/344 Detection FPS: 6.6, Tracking FPS: 23.4, Total FPS: 5.1
# Frame 140/344 Detection FPS: 6.7, Tracking FPS: 17.9, Total FPS: 4.9
# Frame 141/344 Detection FPS: 6.7, Tracking FPS: 22.7, Total FPS: 5.2
# Frame 142/344 Detection FPS: 6.4, Tracking FPS: 18.4, Total FPS: 4.7
# Frame 143/344 Detection FPS: 6.7, Tracking FPS: 19.3, Total FPS: 5.0
# Frame 144/344 Detection FPS: 6.6, Tracking FPS: 23.7, Total FPS: 5.1
# Frame 145/344 Detection FPS: 6.5, Tracking FPS: 19.3, Total FPS: 4.9
# Frame 146/344 Detection FPS: 6.5, Tracking FPS: 18.9, Total FPS: 4.8
# Frame 147/344 Detection FPS: 6.4, Tracking FPS: 23.4, Total FPS: 5.0
# Frame 148/344 Detection FPS: 6.6, Tracking FPS: 22.3, Total FPS: 5.1
# Frame 149/344 Detection FPS: 6.7, Tracking FPS: 21.3, Total FPS: 5.1
# Frame 150/344 Detection FPS: 6.6, Tracking FPS: 24.3, Total FPS: 5.2
# Frame 151/344 Detection FPS: 6.7, Tracking FPS: 25.9, Total FPS: 5.3
# Frame 152/344 Detection FPS: 6.7, Tracking FPS: 18.6, Total FPS: 4.9
# Frame 153/344 Detection FPS: 6.6, Tracking FPS: 19.3, Total FPS: 4.9
# Frame 154/344 Detection FPS: 6.7, Tracking FPS: 24.0, Total FPS: 5.3
# Frame 155/344 Detection FPS: 6.6, Tracking FPS: 24.4, Total FPS: 5.2
# Frame 156/344 Detection FPS: 6.7, Tracking FPS: 21.6, Total FPS: 5.1
# Frame 157/344 Detection FPS: 6.6, Tracking FPS: 22.2, Total FPS: 5.1
# Frame 158/344 Detection FPS: 6.5, Tracking FPS: 12.2, Total FPS: 4.2
# Frame 159/344 Detection FPS: 6.4, Tracking FPS: 11.7, Total FPS: 4.1
# Frame 160/344 Detection FPS: 6.5, Tracking FPS: 12.7, Total FPS: 4.3
# Frame 161/344 Detection FPS: 6.3, Tracking FPS: 11.2, Total FPS: 4.0
# Frame 162/344 Detection FPS: 6.4, Tracking FPS: 13.0, Total FPS: 4.3
# Frame 163/344 Detection FPS: 6.2, Tracking FPS: 9.6, Total FPS: 3.8
# Frame 164/344 Detection FPS: 6.3, Tracking FPS: 5.1, Total FPS: 2.8
# Frame 165/344 Detection FPS: 6.3, Tracking FPS: 11.6, Total FPS: 4.1
# Frame 166/344 Detection FPS: 6.4, Tracking FPS: 12.5, Total FPS: 4.2
# Frame 167/344 Detection FPS: 6.3, Tracking FPS: 11.2, Total FPS: 4.0
# Frame 168/344 Detection FPS: 6.4, Tracking FPS: 21.9, Total FPS: 4.9
# Frame 169/344 Detection FPS: 6.6, Tracking FPS: 19.6, Total FPS: 4.9
# Frame 170/344 Detection FPS: 6.6, Tracking FPS: 22.8, Total FPS: 5.1
# Frame 171/344 Detection FPS: 6.6, Tracking FPS: 25.3, Total FPS: 5.2
# Frame 172/344 Detection FPS: 6.6, Tracking FPS: 23.5, Total FPS: 5.2
# Frame 173/344 Detection FPS: 6.8, Tracking FPS: 20.7, Total FPS: 5.1
# Frame 174/344 Detection FPS: 6.6, Tracking FPS: 19.9, Total FPS: 5.0
# Frame 175/344 Detection FPS: 6.5, Tracking FPS: 20.5, Total FPS: 5.0
# Frame 176/344 Detection FPS: 6.6, Tracking FPS: 24.0, Total FPS: 5.1
# Frame 177/344 Detection FPS: 6.6, Tracking FPS: 26.3, Total FPS: 5.3
# Frame 178/344 Detection FPS: 6.6, Tracking FPS: 24.0, Total FPS: 5.2
# Frame 179/344 Detection FPS: 6.6, Tracking FPS: 23.8, Total FPS: 5.2
# Frame 180/344 Detection FPS: 6.6, Tracking FPS: 24.2, Total FPS: 5.2
# Frame 181/344 Detection FPS: 6.7, Tracking FPS: 19.4, Total FPS: 5.0
# Frame 182/344 Detection FPS: 6.6, Tracking FPS: 22.2, Total FPS: 5.1
# Frame 183/344 Detection FPS: 6.6, Tracking FPS: 17.6, Total FPS: 4.8
# Frame 184/344 Detection FPS: 6.6, Tracking FPS: 24.3, Total FPS: 5.2
# Frame 185/344 Detection FPS: 6.6, Tracking FPS: 21.7, Total FPS: 5.1
# Frame 186/344 Detection FPS: 6.7, Tracking FPS: 24.3, Total FPS: 5.2
# Frame 187/344 Detection FPS: 6.7, Tracking FPS: 18.4, Total FPS: 4.9
# Frame 188/344 Detection FPS: 6.6, Tracking FPS: 16.4, Total FPS: 4.7
# Frame 189/344 Detection FPS: 6.6, Tracking FPS: 20.6, Total FPS: 5.0
# Frame 190/344 Detection FPS: 6.4, Tracking FPS: 16.6, Total FPS: 4.6
# Frame 191/344 Detection FPS: 6.6, Tracking FPS: 26.0, Total FPS: 5.2
# Frame 192/344 Detection FPS: 6.6, Tracking FPS: 24.9, Total FPS: 5.2
# Frame 193/344 Detection FPS: 6.6, Tracking FPS: 24.6, Total FPS: 5.2
# Frame 194/344 Detection FPS: 6.5, Tracking FPS: 22.8, Total FPS: 5.1
# Frame 195/344 Detection FPS: 6.7, Tracking FPS: 20.2, Total FPS: 5.0
# Frame 196/344 Detection FPS: 6.7, Tracking FPS: 24.3, Total FPS: 5.2
# Frame 197/344 Detection FPS: 6.6, Tracking FPS: 17.7, Total FPS: 4.8
# Frame 198/344 Detection FPS: 6.5, Tracking FPS: 17.7, Total FPS: 4.7
# Frame 199/344 Detection FPS: 6.4, Tracking FPS: 8.4, Total FPS: 3.6
# Frame 200/344 Detection FPS: 6.6, Tracking FPS: 23.8, Total FPS: 5.1
# Frame 201/344 Detection FPS: 6.5, Tracking FPS: 25.6, Total FPS: 5.2
# Frame 202/344 Detection FPS: 6.6, Tracking FPS: 19.3, Total FPS: 4.9
# Frame 203/344 Detection FPS: 6.5, Tracking FPS: 26.2, Total FPS: 5.2
# Frame 204/344 Detection FPS: 6.5, Tracking FPS: 23.3, Total FPS: 5.1
# Frame 205/344 Detection FPS: 6.5, Tracking FPS: 23.7, Total FPS: 5.1
# Frame 206/344 Detection FPS: 6.5, Tracking FPS: 13.0, Total FPS: 4.4
# Frame 207/344 Detection FPS: 6.6, Tracking FPS: 24.5, Total FPS: 5.2
# Frame 208/344 Detection FPS: 6.7, Tracking FPS: 24.2, Total FPS: 5.2
# Frame 209/344 Detection FPS: 6.5, Tracking FPS: 17.8, Total FPS: 4.8
# Frame 210/344 Detection FPS: 6.6, Tracking FPS: 16.3, Total FPS: 4.7
# Frame 211/344 Detection FPS: 6.4, Tracking FPS: 11.1, Total FPS: 4.1
# Frame 212/344 Detection FPS: 6.2, Tracking FPS: 9.8, Total FPS: 3.8
# Frame 213/344 Detection FPS: 6.4, Tracking FPS: 10.5, Total FPS: 4.0
# Frame 214/344 Detection FPS: 6.2, Tracking FPS: 11.9, Total FPS: 4.1
# Frame 215/344 Detection FPS: 6.4, Tracking FPS: 10.5, Total FPS: 4.0
# Frame 216/344 Detection FPS: 6.3, Tracking FPS: 10.9, Total FPS: 4.0
# Frame 217/344 Detection FPS: 6.2, Tracking FPS: 10.4, Total FPS: 3.8
# Frame 218/344 Detection FPS: 6.4, Tracking FPS: 14.6, Total FPS: 4.4
# Frame 219/344 Detection FPS: 6.3, Tracking FPS: 18.3, Total FPS: 4.7
# Frame 220/344 Detection FPS: 6.3, Tracking FPS: 16.9, Total FPS: 4.6
# Frame 221/344 Detection FPS: 6.4, Tracking FPS: 13.3, Total FPS: 4.3
# Frame 222/344 Detection FPS: 6.4, Tracking FPS: 17.5, Total FPS: 4.7
# Frame 223/344 Detection FPS: 6.5, Tracking FPS: 19.8, Total FPS: 4.9
# Frame 224/344 Detection FPS: 6.5, Tracking FPS: 21.1, Total FPS: 5.0
# Frame 225/344 Detection FPS: 6.3, Tracking FPS: 20.9, Total FPS: 4.8
# Frame 226/344 Detection FPS: 6.6, Tracking FPS: 18.8, Total FPS: 4.9
# Frame 227/344 Detection FPS: 6.3, Tracking FPS: 25.7, Total FPS: 5.1
# Frame 228/344 Detection FPS: 6.6, Tracking FPS: 18.4, Total FPS: 4.8
# Frame 229/344 Detection FPS: 6.3, Tracking FPS: 18.0, Total FPS: 4.7
# Frame 230/344 Detection FPS: 6.5, Tracking FPS: 20.8, Total FPS: 5.0
# Frame 231/344 Detection FPS: 6.5, Tracking FPS: 17.9, Total FPS: 4.7
# Frame 232/344 Detection FPS: 6.3, Tracking FPS: 17.0, Total FPS: 4.6
# Frame 233/344 Detection FPS: 6.3, Tracking FPS: 14.3, Total FPS: 4.4
# Frame 234/344 Detection FPS: 6.2, Tracking FPS: 21.0, Total FPS: 4.8
# Frame 235/344 Detection FPS: 6.6, Tracking FPS: 15.5, Total FPS: 4.6
# Frame 236/344 Detection FPS: 6.4, Tracking FPS: 23.3, Total FPS: 5.0
# Frame 237/344 Detection FPS: 6.6, Tracking FPS: 16.7, Total FPS: 4.7
# Frame 238/344 Detection FPS: 6.7, Tracking FPS: 15.3, Total FPS: 4.7
# Frame 239/344 Detection FPS: 6.5, Tracking FPS: 54.6, Total FPS: 5.8
# Frame 240/344 Detection FPS: 6.5, Tracking FPS: 21.3, Total FPS: 5.0
# Frame 241/344 Detection FPS: 6.5, Tracking FPS: 22.5, Total FPS: 5.0
# Frame 242/344 Detection FPS: 6.6, Tracking FPS: 26.3, Total FPS: 5.2
# Frame 243/344 Detection FPS: 6.5, Tracking FPS: 70.5, Total FPS: 5.9
# Frame 244/344 Detection FPS: 6.5, Tracking FPS: 23.5, Total FPS: 5.1
# Frame 245/344 Detection FPS: 6.4, Tracking FPS: 27.9, Total FPS: 5.2
# Frame 246/344 Detection FPS: 6.5, Tracking FPS: 18.5, Total FPS: 4.8
# Frame 247/344 Detection FPS: 6.6, Tracking FPS: 69.2, Total FPS: 6.1
# Frame 248/344 Detection FPS: 6.5, Tracking FPS: 30.6, Total FPS: 5.4
# Frame 249/344 Detection FPS: 6.5, Tracking FPS: 24.0, Total FPS: 5.1
# Frame 250/344 Detection FPS: 6.4, Tracking FPS: 15.3, Total FPS: 4.5
# Frame 251/344 Detection FPS: 6.5, Tracking FPS: 14.7, Total FPS: 4.5
# Frame 252/344 Detection FPS: 6.4, Tracking FPS: 23.4, Total FPS: 5.0
# Frame 253/344 Detection FPS: 6.4, Tracking FPS: 25.4, Total FPS: 5.1
# Frame 254/344 Detection FPS: 6.4, Tracking FPS: 15.9, Total FPS: 4.6
# Frame 255/344 Detection FPS: 6.3, Tracking FPS: 24.6, Total FPS: 5.0
# Frame 256/344 Detection FPS: 6.4, Tracking FPS: 23.0, Total FPS: 5.0
# Frame 257/344 Detection FPS: 6.5, Tracking FPS: 28.3, Total FPS: 5.3
# Frame 258/344 Detection FPS: 6.5, Tracking FPS: 17.8, Total FPS: 4.8
# Frame 259/344 Detection FPS: 6.4, Tracking FPS: 18.0, Total FPS: 4.7
# Frame 260/344 Detection FPS: 6.3, Tracking FPS: 19.3, Total FPS: 4.7
# Frame 261/344 Detection FPS: 6.5, Tracking FPS: 18.9, Total FPS: 4.8
# Frame 262/344 Detection FPS: 6.6, Tracking FPS: 60.9, Total FPS: 6.0
# Frame 263/344 Detection FPS: 6.4, Tracking FPS: 61.8, Total FPS: 5.8
# Frame 264/344 Detection FPS: 6.4, Tracking FPS: 19.2, Total FPS: 4.8
# Frame 265/344 Detection FPS: 6.3, Tracking FPS: 15.0, Total FPS: 4.5
# Frame 266/344 Detection FPS: 6.4, Tracking FPS: 55.9, Total FPS: 5.8
# Frame 267/344 Detection FPS: 6.4, Tracking FPS: 50.9, Total FPS: 5.7
# Frame 268/344 Detection FPS: 6.5, Tracking FPS: 56.6, Total FPS: 5.8
# Frame 269/344 Detection FPS: 6.4, Tracking FPS: 53.6, Total FPS: 5.7
# Frame 270/344 Detection FPS: 6.4, Tracking FPS: 54.0, Total FPS: 5.7
# Frame 271/344 Detection FPS: 6.5, Tracking FPS: 54.4, Total FPS: 5.8
# Frame 272/344 Detection FPS: 6.4, Tracking FPS: 35.8, Total FPS: 5.4
# Frame 273/344 Detection FPS: 6.4, Tracking FPS: 52.3, Total FPS: 5.7
# Frame 274/344 Detection FPS: 6.2, Tracking FPS: 42.9, Total FPS: 5.4
# Frame 275/344 Detection FPS: 6.4, Tracking FPS: 47.0, Total FPS: 5.6
# Frame 276/344 Detection FPS: 6.3, Tracking FPS: 47.4, Total FPS: 5.6
# Frame 277/344 Detection FPS: 6.5, Tracking FPS: 31.6, Total FPS: 5.4
# Frame 278/344 Detection FPS: 6.4, Tracking FPS: 27.5, Total FPS: 5.2
# Frame 279/344 Detection FPS: 6.5, Tracking FPS: 25.2, Total FPS: 5.1
# Frame 280/344 Detection FPS: 6.2, Tracking FPS: 26.5, Total FPS: 5.0
# Frame 281/344 Detection FPS: 6.2, Tracking FPS: 19.6, Total FPS: 4.7
# Frame 282/344 Detection FPS: 6.3, Tracking FPS: 22.8, Total FPS: 4.9
# Frame 283/344 Detection FPS: 6.2, Tracking FPS: 25.6, Total FPS: 5.0
# Frame 284/344 Detection FPS: 6.4, Tracking FPS: 26.4, Total FPS: 5.1
# Frame 285/344 Detection FPS: 6.4, Tracking FPS: 22.5, Total FPS: 5.0
# Frame 286/344 Detection FPS: 6.5, Tracking FPS: 25.6, Total FPS: 5.2
# Frame 287/344 Detection FPS: 6.2, Tracking FPS: 26.0, Total FPS: 5.0
# Frame 288/344 Detection FPS: 6.3, Tracking FPS: 21.8, Total FPS: 4.9
# Frame 289/344 Detection FPS: 6.5, Tracking FPS: 30.0, Total FPS: 5.3
# Frame 290/344 Detection FPS: 6.5, Tracking FPS: 24.8, Total FPS: 5.1
# Frame 291/344 Detection FPS: 6.5, Tracking FPS: 21.0, Total FPS: 4.9
# Frame 292/344 Detection FPS: 6.4, Tracking FPS: 30.9, Total FPS: 5.3
# Frame 293/344 Detection FPS: 6.5, Tracking FPS: 32.3, Total FPS: 5.4
# Frame 294/344 Detection FPS: 6.4, Tracking FPS: 30.8, Total FPS: 5.3
# Frame 295/344 Detection FPS: 6.4, Tracking FPS: 29.2, Total FPS: 5.3
# Frame 296/344 Detection FPS: 6.4, Tracking FPS: 33.2, Total FPS: 5.4
# Frame 297/344 Detection FPS: 6.4, Tracking FPS: 31.6, Total FPS: 5.3
# Frame 298/344 Detection FPS: 6.4, Tracking FPS: 23.5, Total FPS: 5.0
# Frame 299/344 Detection FPS: 6.2, Tracking FPS: 33.1, Total FPS: 5.2
# Frame 300/344 Detection FPS: 6.4, Tracking FPS: 29.3, Total FPS: 5.2
# Frame 301/344 Detection FPS: 6.5, Tracking FPS: 25.8, Total FPS: 5.2
# Frame 302/344 Detection FPS: 6.4, Tracking FPS: 35.8, Total FPS: 5.4
# Frame 303/344 Detection FPS: 6.4, Tracking FPS: 25.9, Total FPS: 5.1
# Frame 304/344 Detection FPS: 6.4, Tracking FPS: 28.3, Total FPS: 5.2
# Frame 305/344 Detection FPS: 6.3, Tracking FPS: 28.0, Total FPS: 5.2
# Frame 306/344 Detection FPS: 6.3, Tracking FPS: 27.0, Total FPS: 5.1
# Frame 307/344 Detection FPS: 6.4, Tracking FPS: 19.6, Total FPS: 4.8
# Frame 308/344 Detection FPS: 6.2, Tracking FPS: 24.5, Total FPS: 4.9
# Frame 309/344 Detection FPS: 6.2, Tracking FPS: 22.9, Total FPS: 4.9
# Frame 310/344 Detection FPS: 6.3, Tracking FPS: 26.3, Total FPS: 5.1
# Frame 311/344 Detection FPS: 6.4, Tracking FPS: 26.6, Total FPS: 5.1
# Frame 312/344 Detection FPS: 6.3, Tracking FPS: 18.1, Total FPS: 4.7
# Frame 313/344 Detection FPS: 6.1, Tracking FPS: 37.0, Total FPS: 5.3
# Frame 314/344 Detection FPS: 6.4, Tracking FPS: 34.8, Total FPS: 5.4
# Frame 315/344 Detection FPS: 6.3, Tracking FPS: 27.5, Total FPS: 5.1
# Frame 316/344 Detection FPS: 6.4, Tracking FPS: 26.9, Total FPS: 5.1
# Frame 317/344 Detection FPS: 6.3, Tracking FPS: 28.1, Total FPS: 5.2
# Frame 318/344 Detection FPS: 6.4, Tracking FPS: 25.4, Total FPS: 5.1
# Frame 319/344 Detection FPS: 6.5, Tracking FPS: 24.8, Total FPS: 5.1
# Frame 320/344 Detection FPS: 6.3, Tracking FPS: 11.1, Total FPS: 4.0
# Frame 321/344 Detection FPS: 6.1, Tracking FPS: 11.3, Total FPS: 3.9
# Frame 322/344 Detection FPS: 6.3, Tracking FPS: 11.4, Total FPS: 4.0
# Frame 323/344 Detection FPS: 6.3, Tracking FPS: 11.1, Total FPS: 4.0
# Frame 324/344 Detection FPS: 6.1, Tracking FPS: 15.2, Total FPS: 4.3
# Frame 325/344 Detection FPS: 6.3, Tracking FPS: 17.2, Total FPS: 4.6
# Frame 326/344 Detection FPS: 6.1, Tracking FPS: 12.0, Total FPS: 4.0
# Frame 327/344 Detection FPS: 6.2, Tracking FPS: 12.7, Total FPS: 4.1
# Frame 328/344 Detection FPS: 6.0, Tracking FPS: 10.5, Total FPS: 3.8
# Frame 329/344 Detection FPS: 6.2, Tracking FPS: 13.0, Total FPS: 4.2
# Frame 330/344 Detection FPS: 6.1, Tracking FPS: 20.0, Total FPS: 4.7
# Frame 331/344 Detection FPS: 6.3, Tracking FPS: 19.0, Total FPS: 4.7
# Frame 332/344 Detection FPS: 6.2, Tracking FPS: 26.6, Total FPS: 5.0
# Frame 333/344 Detection FPS: 6.3, Tracking FPS: 25.8, Total FPS: 5.0
# Frame 334/344 Detection FPS: 6.4, Tracking FPS: 23.8, Total FPS: 5.0
# Frame 335/344 Detection FPS: 6.3, Tracking FPS: 46.5, Total FPS: 5.5
# Frame 336/344 Detection FPS: 6.3, Tracking FPS: 44.6, Total FPS: 5.5
# Frame 337/344 Detection FPS: 6.3, Tracking FPS: 51.5, Total FPS: 5.6
# Frame 338/344 Detection FPS: 6.4, Tracking FPS: 22.1, Total FPS: 5.0
# Frame 339/344 Detection FPS: 6.2, Tracking FPS: 43.2, Total FPS: 5.4
# Frame 340/344 Detection FPS: 6.3, Tracking FPS: 20.5, Total FPS: 4.8
# Frame 341/344 Detection FPS: 6.2, Tracking FPS: 59.7, Total FPS: 5.6
# Frame 342/344 Detection FPS: 6.4, Tracking FPS: 58.5, Total FPS: 5.7
# Frame 343/344 Detection FPS: 6.3, Tracking FPS: 21.3, Total FPS: 4.9
# Frame 344/344 Detection FPS: 6.2, Tracking FPS: 47.1, Total FPS: 5.4
